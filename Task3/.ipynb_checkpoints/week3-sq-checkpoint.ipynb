# %% [markdown]
# **Question 3.1**

# %%
masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e+22]
names = ["Sun", "Jupiter", "Saturn", "Neptune", "Uranus", "Earth", "Venus", "Mars", "Mercury", "Moon", "Pluto"]
smaller_than_moon=[]
for mass in masses:
    if mass <= masses[names.index("Moon")]:
        smaller_than_moon.append(mass)

print(f"Masses that are <= than the Moon's mass: {smaller_than_moon}")
lastmass = masses[slice(len(masses)-5,len(masses))]
print(f"The last 5 masses are: {lastmass}")
print(f"The verage mass in the list is: {sum(lastmass)/len(lastmass)} kg.")
# Out:
# Masses that are <= than the Moon's mass: [7.349e+22, 1.25e+22]
# The last 5 masses are: [4.8685e+24, 6.4185e+23, 3.3022e+23, 7.349e+22, 1.25e+22]
# The verage mass in the list is: 1.1853119999999999e+24 kg.

# %% [markdown]
# ![image.png](attachment:10b07811-dca1-48fd-b151-ea69919c98da.png)

# %% [markdown]
# ---------
# **Question 3.2**

# %%
from scipy.constants import G
import math
masses = [1.9891e+30, 1.8986e+27, 5.6846e+26, 
          1.0243e+26, 8.6810e+25, 5.9736e+24, 
          4.8685e+24, 6.4185e+23, 3.3022e+23, 
          7.349e+22, 1.25e22]
radii  = [696340, 71492, 60268, 24764, 
          25559, 6378.1, 6051.8, 3396.2, 
          2439.7, 1738.1, 1195]
names  = ['Sun', 'Jupiter', 'Saturn', 'Neptune', 
          'Uranus', 'Earth', 'Venus', 'Mars', 
          'Mercury', 'Moon', 'Pluto']
esc = []
full_data = {}

for i in range(len(masses)):
    esc.append(math.sqrt(2*G*masses[i]/radii[i]*1000))
    print(f"{names[i]}'s escape velocity is {esc[-1]} with mass {masses[i]: .2e} kg and radius {radii[i]} km.")
    full_data[names[i]] = esc[-1]
print()
print(full_data)
# Out:
# Sun's escape velocity is 617497916.7791921 with mass  1.99e+30 kg and radius 696340 km.
# Jupiter's escape velocity is 59539594.78320213 with mass  1.90e+27 kg and radius 71492 km.
# Saturn's escape velocity is 35483334.49120101 with mass  5.68e+26 kg and radius 60268 km.
# Neptune's escape velocity is 23497467.000065282 with mass  1.02e+26 kg and radius 24764 km.
# Uranus's escape velocity is 21292703.606794767 with mass  8.68e+25 kg and radius 25559 km.
# Earth's escape velocity is 11181247.65336743 with mass  5.97e+24 kg and radius 6378.1 km.
# Venus's escape velocity is 10362705.674286997 with mass  4.87e+24 kg and radius 6051.8 km.
# Mars's escape velocity is 5022708.842483839 with mass  6.42e+23 kg and radius 3396.2 km.
# Mercury's escape velocity is 4250610.719256492 with mass  3.30e+23 kg and radius 2439.7 km.
# Moon's escape velocity is 2375716.4429821675 with mass  7.35e+22 kg and radius 1738.1 km.
# Pluto's escape velocity is 1181650.1475181675 with mass  1.25e+22 kg and radius 1195 km.
#
# {'Sun': 617497916.7791921, 'Jupiter': 59539594.78320213, 'Saturn': 35483334.49120101, 'Neptune': 23497467.000065282, 'Uranus': 21292703.606794767, 'Earth': 11181247.65336743, 'Venus': 10362705.674286997, 'Mars': 5022708.842483839, 'Mercury': 4250610.719256492, 'Moon': 2375716.4429821675, 'Pluto': 1181650.1475181675}

# %% [markdown]
# ---------
# **Question 3.5**

# %%
sum_range = [100,200,300,400,500,600]
sums = []
for r in sum_range:
    sums.append(0)
    for i in range(1,r+1):
        sums[-1] += 1/i**2
conv = True
for i in range(len(sums)-2):
    if sums[i+2]-sums[i+1] > sums[i+1]-sums[i]:
        conv = False
if conv:
    print("The function 1/x^2 converges.")
else:
    print("The function 1/x^2 does not converge.")
# Out:
# The function 1/x^2 converges.

# %% [markdown]
# ---------
# **Question 3.7**

# %%
from math import degrees, atan
def delta(d,D):
    return degrees(2*atan(d/(2*D)))
delta(1,0.5)
# Out:
# 90.0

# %% [markdown]
# ---------
# **Question 3.10**

# %%
from math import pi
def cylinder(r,h):
    A = 2*pi*r*(r+h)
    V = pi*r**2*h
    return A,V
area, volume = cylinder(1,1)
print(f"The area:volume ratio of a cylinder with r=1 and h=1 is {area/volume}")
# Out:
# The area:volume ratio of a cylinder with r=1 and h=1 is 4.0

# %% [markdown]
# ---------
# **Question 3.14**

# %%
import numpy as np
x = [1, 10**2, 2*10, 5.1*20, -4, 4.45*22]
x = np.array(x)
