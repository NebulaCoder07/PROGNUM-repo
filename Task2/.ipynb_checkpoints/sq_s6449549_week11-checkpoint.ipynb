# %% [markdown]
# Answers for Week 1
#
# * Name: Borbala Balas
# * Username: bbalas
# * Student s-number: S6449549
# * Group (AS1, etc.): AS3

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X=1
for i in range (6,0, -1):
   X*=i
X
# Out:
# 720

# %%
def fact(num):
    if num < 2:
        return 1
    else:
        return num*fact(num-1)
fact(6)
# Out:
# 720

# %%
from scipy.constants import h
f = 2.42*10**28
E = h*f
E
# Out:
# 1.6035089762999996e-05

# %%
from scipy.constants import G
m1=7.342*10**22
m2=5.9722*10**24
r=385000.6*1000
F_g = G*m1*m2/r**2
F_g
# Out:
# 1.974384051807571e+20

# %%
from scipy.constants import G, pi
P=365.25*24*3600
a = 1.495*10**11
M = 4*pi**2/(G*P**2)*a**3
M
# Out:
# 1.9845847822369107e+30
