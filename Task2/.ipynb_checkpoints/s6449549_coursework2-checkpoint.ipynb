# %% [markdown]
# # Coursework Set Week 2

# %% [markdown]
# **Common remarks**:
#
# * Deadline: Sunday at 23:59h for the week of this task
# * <font color='red'>Keep all the information in this template unaltered!</font>
#
# **Please fill in the following fields:**
#
# * Name: **Borbála Balás**
# * Username: **bbalas**
# * Student number: **S6449549**
# * Group (AS1, etc.): **AS3**
#
# -----

# %%
totalpoints = currentpoints = 0

# %% [markdown]
# ### Julian Date, a algorithm with some pitfalls (4 pt) <font color='red'><b>COURSEWORK</b></font>
#
# In the online article: [A one-line algorithm for Julian Date](http://adsabs.harvard.edu/full/1983IAPPP..13...16F)
# we find an old and very compact formula for programmable calculators to calculate a Julian Date given a day, month and year.
# A Julian Date is in fact a
# day number corresponding to the number of elapsed days since the beginning of a cycle of 7980 years.
# That makes it a useful tool to calculate how many days there are between two dates.
# The one-line algorithm is valid for the period that started in 1582 with the Gregorian calendar.
# The formula from the article is:
#
#
# ``JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5``
#
# The article notes: **It is important to note that after all divisions in this expression only that portion of the
# quotient to the left of the decimal point is retained and that the quotient is not rounded off.**
#
# * Use your notebook to develop an implementation of this formula.
# * Then create a Python script called ``JD.py`` that asks a user to enter day, month and year. For this date, the script calculates the Julian Date (JD) and prints it. The day can be entered as a floating point number to allow for fractional days.
# * Upload your JD.py to your GitHub account -- ``PROGNUM-repo``, and set your account to be public. In your answer, provide your GitHub repository link.
# * The article provides a test case: the Julian Date for January 4, 1700 is 2341975.5.
#   Use your code to get the correct result, and attach your screen shot in this notebook.&nbsp;
#
# Extend the program on the notebook, so that it can calculate the number of days between two dates in the Gregorian calendar. What is your age expressed in days?
#
# **Answers**:

# %%
days = [31,28,31,30,31,30,31,31,30,31,30,31]

def check_type(string, goal):
    """tries integer conversion for the input and returns the corresponding boolean"""
    if goal == 'int':
        try:
            int(string)
            return True
        except ValueError:
            return False
        
    elif goal == 'float':
        try:
            float(string)
            return True
        except ValueError:
            return False

#-----------------------------------------------------DATE 1--------------------------------------------------------
print('ENTER THE FIRST DATE:')

#------------Inputs---------------
Y1 = input("Enter the year:") #gets the year from user
while not(check_type(Y1, 'int')):
    Y1 = input("The given year is not an integer; please enter a valid year: ")
Y1 = int(Y1)

#--------------       
M1 = input("Enter the month(1-12):") #gets the month from user
while not(check_type(M1, 'int')) or int(M1) > 12:
    M1 = input("The given month is not an integer or is out of range; please enter a valid month: ")
M1 = int(M1)

#--------------        
D1 = input("Enter the day of the month (can be decimal too, must be bigger than 0): ") #gets the day from user
while not(check_type(D1, 'float')) or float(D1)<0 or float(D1)>days[M1-1]:
    D1 = input("The given day is either out of range for that month, or negative, or not a number at all; please enter a valid day: ")
D1 = float(D1)

#------------Calculation---------------
JD1 = 367*Y1 -7*(Y1+(M1+9)//12)//4 - 3*((Y1+(M1-9)//7)//100 + 1)//4 + (275*M1)//9 + D1 + 1721029-0.5 #calculates the first date by the given formula
#--------------------------------------------------------------------------------------------------------------------

#-----------------------------------------------------DATE 2--------------------------------------------------------
print('\nENTER THE SECOND DATE:')

#------------Inputs---------------
Y2 = input("Enter the year:") #gets the year from user
while not(check_type(Y1, 'int')):
    Y2 = input("The given year is not an integer; please enter a valid year: ")
Y2 = int(Y2)

#--------------       
M2 = input("Enter the month(1-12):") #gets the month from user
while not(check_type(M2, 'int')) or int(M2) > 12:
    M2 = input("The given month is not an integer or is out of range; please enter a valid month: ")
M2 = int(M2)

#--------------        
D2 = input("Enter the day of the month (can be decimal too, must be bigger than 0): ") #gets the day from user
while not(check_type(D1, 'float')) or float(D2)<0 or float(D2)>days[M2-1]:
    D2 = input("The given day is either out of range for that month, or negative, or not a number at all; please enter a valid day: ")
D2 = float(D2)

#------------Calculation---------------
JD2 = 367*Y2 -7*(Y2+(M2+9)//12)//4 - 3*((Y2+(M2-9)//7)//100 + 1)//4 + (275*M2)//9 + D2 + 1721029-0.5 #calculates the second date by the given formula
#--------------------------------------------------------------------------------------------------------------------


#---------------Output-----------------
if JD1>JD2:
    print(f'The first date is {JD1-JD2} days after the second date.')
elif JD2>JD1:
    print(f'The first date is {JD2-JD1} days before the second date.')
else:
    print('The two entered dates are the same.')
# Out:
# ENTER THE FIRST DATE:
# Enter the year: 2024
# Enter the month(1-12): 2
# Enter the day of the month (can be decimal too, must be bigger than 0):  5
# ENTER THE SECOND DATE:
# Enter the year: 2026
# Enter the month(1-12): 8
# Enter the day of the month (can be decimal too, must be bigger than 0):  17
# The first date is 924.0 days before the second date.

# %% [markdown]
# *Code for task b)*

# %% [markdown]
# ![Screenshot_20260220_104848.png](attachment:c8b8bbea-d06a-4c1c-9e61-f5b0b44750f6.png) <br> *Output for 4 jan 1700*

# %% [markdown]
# ![Screenshot from 2026-02-20 10-41-27.png](attachment:c0585a98-cbc7-4b2e-8cef-e0c687b603ec.png) <br> *Output for my age*

# %% [markdown]
# **Link to repository:** https://github.com/NebulaCoder07/PROGNUM-repo.git

# %%
# Leave unaltered
totalpoints += 4
currentpoints += 0.0

# %% [markdown]
# ###  Calculating the roots of a second degree polynomial (3 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Use your notebook to develop the necessary code and then which solves for the roots
# of $f(x)=ax^2+bx+c$ for values of ``a``, ``b`` and ``c`` entered by a user of your program.
# All the required information related to this question is included in the notebook about conditions.
#
# You have to remember that
#
# $$f(x)=ax^2+bx+c$$
#
# has two solutions:
#
# $$x_1=\frac{-b + \sqrt{b^2-4ac}}{2a} \quad\text{and}\quad x_2=\frac{-b - \sqrt{b^2-4ac}}{2a}$$
#
# only if:
#
# $$\begin{split}D= b^2-4ac>0\end{split}$$
#
# It has one solution if $D == 0$ and no solutions (at least no real solutions) if $D < 0$.
#
# * Use the ``if,elif,else`` construct to print either two solutions, one solution or an message that no solutions
#  could be found.
# * Use f-strings for your output if there are solutions.
# * Include your code with an input example and its output in your notebook.
# * Use your notebook code to create a script called ``abc.py``.
# * On Terminal, run your python script, screenshot the result, and attach the it here.
#
# **Answer**:

# %%
import math
def type_check(string):
    try:
        float(string)
        return True
    except ValueError:
        return False
    
a = input('Enter the coefficient of the quadratic term: ')
while not(type_check(a)):
    a = input('Please enter a number: ')
a = float(a)

b = input('Enter the coefficient of the linear term: ')
while not(type_check(b)):
    b = input('Please enter a number: ')
b = float(b)

c = input('Enter the constant term: ')
while not(type_check(c)):
    c = input('Please enter a number: ')
c = float(c)

D = b**2-4*a*c

if D>0:
    print(f"The two solutions for the quadratic equation ({a})*x^2+({b})*x+({c})=0 are {(-b+math.sqrt(D))/(2*a)} and {(-b-math.sqrt(D))/(2*a)}.")
elif D == 0:
    print(f"The quadratic equation ({a})*x^2+({b})*x+({c})=0 are has one solution, which is {-b/(2*a)}.")
else:
    print(f"The quadratic equation ({a})*x^2+({b})*x+({c})=0 are has no solutions.")
# Out:
# Enter the coefficient of the quadratic term:  1
# Enter the coefficient of the linear term:  6
# Enter the constant term:  3
# The two solutions for the quadratic equation (1.0)*x^2+(6.0)*x+(3.0)=0 are -0.5505102572168221 and -5.449489742783178.

# %% [markdown]
# ![Screenshot_20260220_134110.png](attachment:4a59ea5c-7d79-41d5-ba93-072ee6f953cc.png) <br> *Eg.: Output for a=4, b=5, c=1, here the equation has two solutions*

# %%
# Leave unaltered
totalpoints += 3
currentpoints += 0.0

# %% [markdown]
# ### Uniqueness in lists using the `set` object (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given two lists with a number of gamma ray bursts per night for two different periods
#
# ```python
#     night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
#     night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
# ```
#
# Use Python sequence type `set` to create a **list**:
#
# 1. with values that are both in `night1` and `night2`.
# 1. with values that are the difference between `night1` and `night2`.
# 1. with values that contains all items from both sets, duplicates are excluded.
# 1. after an update of `night1` by removing all its elements that are not available in `night2`.
#
# **Answers**:

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

night1 = set(night1)
night2 = set(night2)

print('1st task:',set.intersection(night1,night2))
print('2nd task:',set.difference(night1,night2))
print('3rd task:',set.union(night1,night2))

night1 = set.difference(night1,set.difference(night1,night2))
print('4th task:',night1)
# Out:
# 1st task: {0, 1, 2, 3, 4}
# 2nd task: {9, 5, 7}
# 3rd task: {0, 1, 2, 3, 4, 5, 7, 9}
# 4th task: {0, 1, 2, 3, 4}

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Change a value in a dictionary (2 pt) <font color='red'><b>COURSEWORK</b></font>
#
# Given the Python dictionary:
#
# ```python
# planetsmass = { 'Mercury' : 0.33,
#                 'Venus'   : 4.87, 'Earth'   : 5.98,
#                 'Mars'    : 0.65, 'Jupiter' : 1900,
#                 'Saturn'  :  570, 'Uranus'  :  87,
#                 'Neptune' :  100, 'Pluto'   :  0.7 }
# ```
#
# 1. Extract from this dictionary a Python **list** with only the names of the objects.
# 1. Print the mass of Venus in Earth masses.
# 1. Remove Pluto from your dictionary.
# 1. Add Planet Nine with mass 29.3 to the dictionary.
# 1. Print the modified dictionary.
#
#
# **Answer**:

# %%
planetsmass = { 'Mercury' : 0.33,
                'Venus'   : 4.87, 'Earth'   : 5.98,
                'Mars'    : 0.65, 'Jupiter' : 1900,
                'Saturn'  :  570, 'Uranus'  :  87,
                'Neptune' :  100, 'Pluto'   :  0.7 }
listed_names = list(planetsmass.keys())
print(f'The keys in the dictionary planetsmass are: {", ".join(listed_names)}.')
print(f"Venus's mass in Earth masses is {planetsmass['Venus']/planetsmass['Earth']} M_Earth.")
planetsmass.popitem()
planetsmass["Planet Nine"] = 29.3
print(f"The modified dictionary is: {planetsmass}.")
# Out:
# The keys in the dictionary planetsmass are: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune, Pluto.
# Venus's mass in Earth masses is 0.81438127090301 M_Earth.
# The modified dictionary is: {'Mercury': 0.33, 'Venus': 4.87, 'Earth': 5.98, 'Mars': 0.65, 'Jupiter': 1900, 'Saturn': 570, 'Uranus': 87, 'Neptune': 100, 'Planet Nine': 29.3}.

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ### Apply NumPy functions to data (2pt) <font color='red'><b>COURSEWORK</b></font>
#
# * Create a NumPy array `x` with 100 angles in degrees between 0 and 360 degrees using ``np.linspace()``
# * Calculate the ``np.sinc(x)`` values of ``x``, with ``x`` in radians. The definition of the sinc function is:
#
#   $$\mathrm{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$
#
# * Print the first 10 values of the result.
#
# **Answer**

# %%
import numpy as np
from math import pi

x = np.linspace(0,360,100)
sinc_values = np.sinc((pi/180*x))
print(f"The first ten values for the corresponding x_i are: {', '.join(map(str,sinc_values[:10]))} .")
# Out:
# The first ten values for the corresponding x_i are: 1.0, 0.9933873652026526, 0.9737067586290185, 0.9414256204351539, 0.8973083104869668, 0.842394523762147, 0.7779700080257624, 0.705530483396262, 0.6267398696896891, 0.5433840979844083 .

# %%
# Leave unaltered
totalpoints += 2
currentpoints += 0.0

# %% [markdown]
# ## Finishing up
#
# **Please read the section about your report in the task documentation very carefully before submitting it to BrightSpace.**
#
# ------------

# %% [markdown]
# ## T.A. Grading

# %%
# Leave unaltered
taskgrade = round(10*currentpoints/totalpoints, 1) if totalpoints != 0 else 0
print(f"Total number of points: {totalpoints}. Student score: {currentpoints}.  Task Grade = {taskgrade}")
# Out:
# Total number of points: 13. Student score: 0.0.  Task Grade = 0.0
